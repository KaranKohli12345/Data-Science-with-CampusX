# %% [markdown]
# ## Machine Learning

# %% [markdown]
# `
# Machine Learning is a field of Computer Science that uses statistical techniques to give computer systems
# the abiltiy to "learn" with data, without being explicitly programmed.
# `

# %% [markdown]
# ![ML.jpg](attachment:ceb4f5f7-7521-485f-9a44-d298b2d7d47c.jpg)

# %% [markdown]
# **Machine learning boomed after 2010 because** -
#
# - Data availability and storage
# - Hardware advancement to process that data

# %% [markdown]
# ![ML and DL.png](attachment:bcde7089-62d3-4b07-9da2-815e96b75141.png)

# %% [markdown]
# ## AI vs ML vs DL vs DS

# %% [markdown]
# ![DS_MLRelationship.webp](attachment:b1665f71-63c7-40ff-ae96-e9f5d61f45a4.webp)

# %% [markdown]
# **Human intelligence**
#
# - pattern recognition
# - emotional intelligence
# - creativity
# - imagination

# %% [markdown]
# **AI** (subset of Human intelligence)
#
# - pattern recognition only for now

# %% [markdown]
# #### Evolution of AI

# %% [markdown]
# **Symbolic AI**
#
# - Expert systems (use knowledge base)
#
# **Limitations**
#
# - domain specific (which requires fuzzy logic like image classifcation)

# %% [markdown]
# ![expert-systems-in-ai2.png](attachment:abe1e52b-1556-4473-9031-dc9223d2ce6e.png)

# %% [markdown]
# - Machine Learning came next
