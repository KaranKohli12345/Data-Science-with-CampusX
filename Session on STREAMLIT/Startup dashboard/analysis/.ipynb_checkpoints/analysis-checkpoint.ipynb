# %%
import pandas as pd

# %%
df = pd.read_csv(r'startup_funding.csv')

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df['Investors Name'] = df['Investors Name'].fillna('Undisclosed')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3044 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
sorted(list(df['Startup Name'].unique()))
# Out:
# ['"BYJU\\\\\'S"',
#  '#Fame',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '20Dresses',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
# ...

# %%
len(list(df['Startup Name'].unique()))
# Out:
# 2459

# %%
sorted(list(df['Investors Name'].unique()))
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"',
#  '021 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd (through crowdfunding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '3 undisclosed investors',
#  '3One4 Capital',
#  '3one4 Capital, Mumbai Angels, Aarin Capital',
#  '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners',
#  '3one4 capital',
#  '500 Startups',
#  '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave',
#  '500 Startups, IvyCap Ventures',
#  '500 Startups, Littlerock, Singularity Ventures',
#  '500 Startups, Mato Peric & Others',
#  '500 Startups, Mato Peric, TracxnLabs',
#  '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta',
#  '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham',
#  '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai',
#  '50K Ventures',
# ...

# %%
len(df['Investors Name'].unique())
# Out:
# 2412

# %%
df.shape
# Out:
# (3044, 10)

# %%
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.drop(columns=['Remarks'], inplace=True)

# %%
df.set_index('Sr No', inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy':'date',
    'Startup Name':'startup',
    'Industry Vertical':'vertical',
    'SubVertical':'subvertical',
    'City  Location':'city',
    'Investors Name':'investors',
    'InvestmentnType':'round',
    'Amount in USD':'amount'
    }, inplace=True)

# %%
# 0 -> undisclosed

df['amount'].fillna('0', inplace=True)

# %%
df['amount']=df['amount'].str.replace(',','')
df['amount']=df['amount'].str.replace('undisclosed','0')
df['amount']=df['amount'].str.replace('unknown','0')
df['amount']=df['amount'].str.replace('Undisclosed','0')

# %%
df = df[df['amount'].str.isdigit()]

# %%
df['amount']=df['amount'].astype('int64')

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round     amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   object
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3029 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 213.0+ KB

# %%
list(df['amount'])
# Out:
# [200000000,
#  8048394,
#  18358860,
#  3000000,
#  1800000,
#  9000000,
#  150000000,
#  6000000,
#  70000000,
#  50000000,
#  20000000,
#  12000000,
#  30000000,
#  5900000,
#  2000000,
#  50000000,
#  231000000,
#  150000000,
#  486000,
#  1500000,
#  0,
#  12000000,
#  26000000,
#  17411265,
#  1300000,
#  135000000,
#  300000,
#  220000000,
#  15800000,
#  283000000,
#  200000000,
#  1000000000,
#  45000000,
#  585000000,
#  0,
#  4500000,
#  3300000,
#  6000000,
#  5000000,
#  18000000,
#  1000000,
#  10000000,
#  450000000,
#  5000000,
#  20000000,
#  5000000,
#  1600000,
#  140000000,
#  38080000,
#  125000000,
#  11000000,
#  51000000,
#  37000000,
#  500000,
#  110000000,
#  15000000,
#  6590000,
#  1000000,
#  0,
#  70000000,
#  3900000000,
#  19000000,
#  2500000,
#  145000,
#  1000000,
#  38080000,
#  500000,
#  150000000,
#  60000000,
#  16000000,
#  5750000,
#  2500000,
#  1000000,
#  319605,
#  51000000,
#  10000000,
#  9000000,
#  75000000,
#  26000000,
#  2500000,
# ...

# %%
def to_inr(dollar):
    inr = dollar * 83.86
    return inr/10000000

# %%
to_inr(20000000)
# Out:
# 167.72

# %%
df['amount']=df['amount'].apply(to_inr)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1677.200000
# ...

# %%
df['date']=pd.to_datetime(df['date'],format='%d/%m/%Y',errors='coerce')

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1677.200000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3022 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3029 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df['date'].dt.month
# Out:
# Sr No
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
#        ...
# 3040    1.0
# 3041    1.0
# 3042    1.0
# 3043    1.0
# 3044    1.0
# Name: date, Length: 3029, dtype: float64

# %%
df=df.dropna(subset=['date','startup','vertical','city','investors','round','amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2842 non-null   datetime64[ns]
#  1   startup      2842 non-null   object
#  2   vertical     2842 non-null   object
#  3   subvertical  2095 non-null   object
#  4   city         2842 non-null   object
#  5   investors    2842 non-null   object
#  6   round        2842 non-null   object
#  7   amount       2842 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 199.8+ KB

# %%
df.to_csv('startup_cleaned.csv',index=False)

# %%
sorted(list(df['investors'].unique()))
# Out:
# ['"Kedaraa Capital, Ontario Teachers\\\\\'"',
#  '021 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd (through crowdfunding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '3 undisclosed investors',
#  '3One4 Capital',
#  '3one4 Capital, Mumbai Angels, Aarin Capital',
#  '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners',
#  '3one4 capital',
#  '500 Startups',
#  '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave',
#  '500 Startups, IvyCap Ventures',
#  '500 Startups, Littlerock, Singularity Ventures',
#  '500 Startups, Mato Peric & Others',
#  '500 Startups, Mato Peric, TracxnLabs',
#  '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta',
#  '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham',
#  '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai',
#  '50K Ventures',
# ...

# %%
len(df['investors'].str.split(',').sum())
# Out:
# 5441

# %%
set(df['investors'].str.split(',').sum())
# Out:
# {'',
#  'Abhishek Gupta',
#  'Rajesh Sawheny ',
#  ' Exfinity Venture Partners & Others',
#  ' Fundnel',
#  'Incubate Fund India',
#  '\\\\xc2\\\\xa0 ru-Net',
#  'Individual investors',
#  ' Anandbir Singh',
#  ' Axilor Ventures and Binny Bansal',
#  ' Aspada Investment',
#  ' Pratik Singhi',
#  'RoundGlass Partners',
#  'Pawan Borle',
#  'Prakhar Bumb',
#  'Ant Financials',
#  'Skycatcher Fund',
#  ' IFC',
#  'Not Disclosed',
#  ' Perceptive Advisors',
#  '\\\\xc2\\\\xa0 Kaleden Holdings',
#  ' Trust Capital',
#  'Micromax Informatics Ltd',
#  'Bitkemy Ventures',
#  ' Nirvana Digital Investment Holding Co Ltd',
#  'GEMS Advisory',
#  ' Ashish Hemrajani',
#  ' Aaruha Technology Fund',
#  ' Jaspreet Bindra',
#  ' Altimeter Capital',
#  'VentureNursery',
#  'Payal Syal',
#  'Pravin Agarwala & others',
#  ' India Alternatives',
#  'Stellaris Venture Partners',
#  ' Sanjay Mehta',
#  'Sumit Gandhi',
#  'Manpreet Singh',
#  ' Founder Collective',
#  ' Ashish Chand',
#  'Mohit Gulati',
# ...

# %%
len(set(df['investors'].str.split(',').sum()))
# Out:
# 3454

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['investors'].str.contains('Bharat Gupta')].head()[['date','startup','vertical','city','round','amount']]
# Out:
#             date  startup           vertical     city         round  amount
# Sr No
# 522   2017-10-03  ChqBook  Consumer Internet  Gurgaon  Seed Funding     0.0
# 2016  2016-01-06    Qdesq        Real Estate  Gurgaon  Seed Funding     0.0

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1677.200000
# ...

# %%
df[df['investors'].str.contains(' IDG Ventures')].groupby('startup')['amount'].sum().sort_values(ascending=False)
# Out:
# startup
# Lenskart                 503.160000
# CureFit                  209.650000
# Bizongo                  184.492000
# Curefit                  125.790000
# Xpressbees               104.825000
# FirstCry.com              83.860000
# POPxo                     72.119600
# \\xc2\\xa0CloudCherry     50.316000
# Sigtuple                  48.638800
# RentMojo                  41.930000
# Aasaanjobs                41.930000
# PlaySimple                33.544000
# Tripoto                   30.117271
# Active.ai                 25.158000
# Heckyl                    22.642200
# Little Black Book          8.386000
# Cloudcherry Analytics      8.386000
# Name: amount, dtype: float64

# %%
df[df['investors'].str.contains(' IDG Ventures')].duplicated()
# Out:
# Sr No
# 102     False
# 259     False
# 310     False
# 505     False
# 528     False
# 673     False
# 964     False
# 1012    False
# 1211    False
# 1215    False
# 1395    False
# 1506    False
# 1536    False
# 1673    False
# 1933    False
# 1950    False
# 2329    False
# 2571    False
# 2819    False
# dtype: bool

# %%
(df[df['investors'].str.contains(' IDG Ventures')]).shape
# Out:
# (19, 8)

# %%
type(df[df['investors'].str.contains(' IDG Ventures')].groupby('startup')['amount'].sum().sort_values(ascending=False))
# Out:
# pandas.core.series.Series

# %%
df[df['investors'].str.contains(' IDG Ventures')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df[df['investors'].str.contains(' IDG Ventures')].groupby('round')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1677.200000
# ...

# %%
df ['year'] = df['date'].dt.year

# %%
df[df['investors'].str.contains(' IDG Ventures')].groupby('year')['amount'].sum().plot(kind='line')
# Out:
# <Axes: xlabel='year'>

# %%
round(df['amount'].sum())
# Out:
# 306540
